# %% [markdown]
# ## We want to practice git using this repo

# %% [markdown]
# #### Describe the uses of the following git commands

# %% [markdown]
# 1. git status

# %% [markdown]
# 2. git add

# %% [markdown]
# 3. git commit

# %% [markdown]
# 4. git clone

# %% [markdown]
# 5. git push
